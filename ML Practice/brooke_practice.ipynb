# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %%
data1 = np.zeros((1000,3))
data2 = np.zeros((1000,3))

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-1,high=1)
    y = np.random.uniform(low=-1,high=1)
    if (x**2 + y**2)<1:
        data1[counter,0] = x
        data1[counter,1] = y
        data1[counter,2] = 1
        counter+=1

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-2,high=2)
    y = np.random.uniform(low=-2,high=2)
    if (x**2 + y**2)>1:
        if (x**2 + y**2)<3:
            data2[counter,0] = x
            data2[counter,1] = y
            data2[counter,2] = 2
            counter+=1


practice1 = np.concatenate((data1,data2))
np.random.shuffle(practice1)

print(practice1)

plt.scatter(data1[:,0], data1[:,1],color="red", alpha=0.3)
plt.scatter(data2[:,0], data2[:,1],color="blue",alpha=0.3)
# Out:
# [[ 0.14047434  0.83000516  1.        ]
#  [-0.43566561  0.9591098   2.        ]
#  [-0.60061247  1.20051774  2.        ]
#  ...
#  [-0.70133519  0.67319752  1.        ]
#  [-0.45424953 -1.34744486  2.        ]
#  [ 1.26387026  1.12858417  2.        ]]

# %%
data_coords = practice1[0:1500, 0:2]
data_labels = practice1[0:1500, 2]

testing_coords = practice1[1500: , 0:2]
testing_labels = practice1[1500: , 2]

rbf_svc = svm.SVC(kernel= 'rbf')
rbf_svc.kernel
rbf_svc.fit(data_coords, data_labels)
# Out:
# SVC()

# %%
testing1 = rbf_svc.predict(testing_coords)
count = 0
for i in range(500):
    if(testing1[i] == testing_labels[i]):
        count += 1
    
print("accuracy is equal to:", count/500)
# Out:
# accuracy is equal to: 0.998

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))
data3 = np.zeros((1000,4))


x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1

x1 = -1
y1 = 2
z1 = -1.5
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data3[counter,0] = x2
        data3[counter,1] = y2
        data3[counter,2] = z2
        data3[counter,3] = 3
        counter+=1

practice2 = np.concatenate((data1,data2,data3))
np.random.shuffle(practice2)
print(practice2)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
ax.scatter3D(data3[:,0], data3[:,1], data3[:,2], color = "red",alpha=0.2)
plt.show()
# Out:
# [[ 3.62524982 -2.89919022 -1.71092842  2.        ]
#  [ 2.52158065 -2.40118485 -1.19463822  2.        ]
#  [ 3.89155999 -1.3685781  -1.3415475   2.        ]
#  ...
#  [ 3.46377067 -2.71726944 -1.63414639  1.        ]
#  [ 3.85601209 -2.39769438 -1.4146339   1.        ]
#  [ 2.84933847 -2.56775621 -1.30016299  2.        ]]

# %%
datacoords = practice2[0:2500, 0:3]
datalbls = practice2[0:2500, 3]

testingcoords = practice2[2500:, 0:3]
testinglbls = practice2[2500:, 3]

machine2 = svm.SVC()

machine2.fit(datacoords, datalbls)
# Out:
# SVC()

# %%
testing2 = machine2.predict(testingcoords)
count = 0
for i in range(500):
    if(testing2[i] == testinglbls[i]):
        count += 1
    
print("accuracy is equal to:", count/500)
# Out:
# accuracy is equal to: 0.624

# %%
print(testinglbls)
# Out:
# [1. 3. 3. 1. 1. 2. 3. 1. 1. 3. 3. 2. 2. 1. 2. 3. 2. 1. 3. 1. 1. 2. 3. 3.
#  1. 2. 3. 3. 3. 1. 2. 2. 2. 3. 2. 3. 3. 2. 3. 2. 1. 3. 3. 2. 3. 2. 2. 3.
#  3. 3. 2. 3. 1. 1. 1. 3. 2. 2. 3. 2. 2. 1. 1. 1. 3. 1. 2. 3. 2. 1. 2. 2.
#  3. 1. 3. 3. 2. 2. 3. 2. 2. 3. 3. 1. 2. 3. 2. 2. 2. 2. 2. 1. 2. 2. 2. 2.
#  2. 1. 3. 1. 1. 1. 3. 2. 1. 3. 2. 2. 1. 3. 1. 3. 2. 2. 2. 2. 3. 2. 2. 1.
#  2. 1. 1. 2. 3. 3. 3. 1. 2. 3. 2. 1. 1. 3. 2. 2. 1. 1. 1. 2. 1. 2. 3. 2.
#  2. 2. 3. 2. 1. 1. 2. 3. 2. 1. 3. 2. 3. 3. 3. 2. 3. 3. 2. 1. 1. 3. 1. 1.
#  1. 3. 2. 2. 2. 3. 2. 1. 3. 2. 1. 3. 1. 1. 3. 2. 3. 3. 2. 2. 1. 2. 2. 3.
#  1. 1. 3. 1. 2. 1. 2. 3. 3. 2. 3. 3. 3. 2. 2. 1. 2. 2. 1. 2. 3. 1. 3. 3.
#  2. 3. 2. 3. 1. 3. 2. 1. 3. 1. 1. 1. 3. 2. 1. 2. 2. 3. 2. 3. 1. 2. 3. 3.
#  2. 1. 1. 1. 1. 1. 3. 3. 2. 2. 2. 3. 3. 2. 1. 2. 1. 1. 3. 1. 2. 3. 2. 3.
#  1. 1. 3. 3. 2. 2. 2. 3. 2. 3. 3. 3. 2. 1. 2. 2. 3. 2. 2. 1. 2. 3. 1. 1.
#  3. 2. 1. 2. 3. 3. 2. 2. 3. 1. 2. 3. 3. 1. 1. 1. 3. 1. 3. 1. 2. 2. 1. 2.
# ...

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))

x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = 3
y1 = -2
z1 = 0
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1


practice3 = np.concatenate((data1,data2))
np.random.shuffle(practice3)
print(practice3)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
plt.show()
# Out:
# [[ 3.05644889 -1.43315376 -0.64105925  2.        ]
#  [ 3.24210427 -1.64897711 -0.38355588  1.        ]
#  [ 3.21876483 -1.60108191  0.46816767  2.        ]
#  ...
#  [ 3.36233684 -2.43499076 -0.57820025  1.        ]
#  [ 3.5901379  -2.58554645 -0.40825933  2.        ]
#  [ 2.73776302 -2.26554984 -0.47433648  2.        ]]

# %%
#training a support vector machine to classify practice3

#taking the x,y coordinates from the first 1800 points
training_features = practice3[0:1800,0:3]
#taking the labels from the first 1800 points
training_labels = practice3[0:1800,3]

#taking coords from 200 last points
testing_features = practice3[1800:,0:3]
#taking labels from 200 last points
testing_labels = practice3[1800:,3]

machine  = svm.SVC()

machine.fit(training_features, training_labels)
# Out:
# SVC()

# %%
testing = machine.predict(testing_features)
count = 0
for i in range(200):
    if testing_labels[i] == testing[i]:
        count += 1

print("accuracy=", count/200)
# Out:
# accuracy= 0.835
