# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn

from sklearn import svm

#test

# %%
data1 = np.zeros((1000,3))
data2 = np.zeros((1000,3))

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-1,high=1)
    y = np.random.uniform(low=-1,high=1)
    if (x**2 + y**2)<1:
        data1[counter,0] = x
        data1[counter,1] = y
        data1[counter,2] = 1
        counter+=1

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-2,high=2)
    y = np.random.uniform(low=-2,high=2)
    if (x**2 + y**2)>1:
        if (x**2 + y**2)<3:
            data2[counter,0] = x
            data2[counter,1] = y
            data2[counter,2] = 2
            counter+=1


practice1 = np.concatenate((data1,data2))
np.random.shuffle(practice1)

print(practice1)

plt.scatter(data1[:,0], data1[:,1],color="red", alpha=0.3)
plt.scatter(data2[:,0], data2[:,1],color="blue",alpha=0.3)
# Out:
# [[-1.47607498  0.06213449  2.        ]
#  [ 1.28360321 -0.70492173  2.        ]
#  [-0.89637762 -1.00533167  2.        ]
#  ...
#  [-0.89027527 -0.0039343   1.        ]
#  [ 0.85509274  0.72677603  2.        ]
#  [ 0.05928871  1.61353978  2.        ]]

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))
data3 = np.zeros((1000,4))


x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = -2
y1 = -1
z1 = -3
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1

x1 = -1
y1 = 2
z1 = -1.5
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data3[counter,0] = x2
        data3[counter,1] = y2
        data3[counter,2] = z2
        data3[counter,3] = 3
        counter+=1

practice2 = np.concatenate((data1,data2,data3))
np.random.shuffle(practice2)
print(practice2)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
ax.scatter3D(data3[:,0], data3[:,1], data3[:,2], color = "red",alpha=0.2)
plt.show()
# Out:
# [[-1.46036877  2.53593387 -1.36759576  3.        ]
#  [-2.08028235 -0.52190363 -3.39118158  2.        ]
#  [-1.17322634 -0.29741663 -2.99630886  2.        ]
#  ...
#  [ 3.922371   -1.89070272 -0.79016605  1.        ]
#  [-2.22843486 -1.29495501 -3.24343759  2.        ]
#  [-1.88934242 -0.60345312 -3.51403379  2.        ]]

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))

x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = 3
y1 = -2
z1 = 0.5
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1


practice3 = np.concatenate((data1,data2))
np.random.shuffle(practice3)
print(practice3)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
plt.show()
# Out:
# [[ 3.19587117 -2.29261267  1.12869983  2.        ]
#  [ 3.90547494 -2.05830533  0.89610855  2.        ]
#  [ 2.83087265 -2.61379492 -0.74695072  1.        ]
#  ...
#  [ 3.43958904 -2.80540178 -0.89505506  1.        ]
#  [ 3.5473786  -2.26275318 -0.75441401  1.        ]
#  [ 2.60546152 -2.13521958  0.36880754  2.        ]]

# %%
trainingfit_feature_x = practice3[0:1500, 0:3]
trainingfit_label_y = practice3[0:1500, 3]

testingpredict_feature_x = practice3[1500: , 0:3]
testingpredict_label_y = practice3[1500: , 3]

learner = svm.SVC()

learner.fit(trainingfit_feature_x, trainingfit_label_y)

working = learner.predict(testingpredict_feature_x)
count = 0
for i in range(500):
    if testingpredict_label_y[i] == working[i]:
        count += 1
    
print("accuracy=", count/500)
# Out:
# accuracy= 0.964
