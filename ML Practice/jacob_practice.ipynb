# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %%
data1 = np.zeros((1000,3))
data2 = np.zeros((1000,3))

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-1,high=1)
    y = np.random.uniform(low=-1,high=1)
    if (x**2 + y**2)<1:
        data1[counter,0] = x
        data1[counter,1] = y
        data1[counter,2] = 1
        counter+=1

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-2,high=2)
    y = np.random.uniform(low=-2,high=2)
    if (x**2 + y**2)>1:
        if (x**2 + y**2)<3:
            data2[counter,0] = x
            data2[counter,1] = y
            data2[counter,2] = 2
            counter+=1


practice1 = np.concatenate((data1,data2))
np.random.shuffle(practice1)

print(practice1)

plt.scatter(data1[:,0], data1[:,1],color="red", alpha=0.3)
plt.scatter(data2[:,0], data2[:,1],color="blue",alpha=0.3)
# Out:
# [[ 1.280492    0.98367573  2.        ]
#  [-0.72533725 -0.22151006  1.        ]
#  [-1.16974516 -1.25760645  2.        ]
#  ...
#  [-1.20628766  0.45317043  2.        ]
#  [ 1.28251915  0.01744811  2.        ]
#  [ 0.85739838  0.59463042  2.        ]]

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))
data3 = np.zeros((1000,4))


x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = -2
y1 = -1
z1 = -3
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1

x1 = -1
y1 = 2
z1 = -1.5
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data3[counter,0] = x2
        data3[counter,1] = y2
        data3[counter,2] = z2
        data3[counter,3] = 3
        counter+=1

practice2 = np.concatenate((data1,data2,data3))
np.random.shuffle(practice2)
print(practice2)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
ax.scatter3D(data3[:,0], data3[:,1], data3[:,2], color = "red",alpha=0.2)
plt.show()
# Out:
# [[-1.48945896 -1.25555364 -2.4633323   2.        ]
#  [-0.82635242  1.45753564 -1.07849796  3.        ]
#  [-0.80555902  1.40162488 -1.54779885  3.        ]
#  ...
#  [-1.22190991  1.60464858 -1.61432883  3.        ]
#  [-1.37675964 -1.94451217 -3.42081278  2.        ]
#  [ 2.41188515 -1.14789154 -0.84836312  1.        ]]

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))

x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = 3
y1 = -2
z1 = 0
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1


practice3 = np.concatenate((data1,data2))
np.random.shuffle(practice3)
print(practice3)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
plt.show()
# Out:
# [[ 2.76568683 -1.47439312 -0.37369485  1.        ]
#  [ 2.35938609 -1.47150878 -0.65669583  1.        ]
#  [ 2.79955157 -1.68880037 -0.19727373  2.        ]
#  ...
#  [ 3.15153381 -1.65219719  0.47285524  2.        ]
#  [ 3.58416797 -1.88956578 -1.24079601  1.        ]
#  [ 3.45091838 -2.52765624 -0.91336395  1.        ]]

# %%
#training a support vector machine to classify practice3

#taking the x,y coordinates from the first 1800 points
training_features = practice3[0:1800,0:3]
#taking the labels from the first 1800 points
training_labels = practice3[0:1800,3]

#taking coords from 200 last points
testing_features = practice3[1800:,0:3]
#taking labels from 200 last points
testing_labels = practice3[1800:,3]

machine  = svm.SVC()

machine.fit(training_features, training_labels)
# Out:
# SVC()

# %%
testing = machine.predict(testing_features)
count = 0
for i in range(200):
    if testing_labels[i] == testing[i]:
        count += 1

print("accuracy=", count/200)
# Out:
# accuracy= 0.84
