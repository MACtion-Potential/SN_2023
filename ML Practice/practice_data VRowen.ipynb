# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
data1 = np.zeros((1000,3))
data2 = np.zeros((1000,3))

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-1,high=1)
    y = np.random.uniform(low=-1,high=1)
    if (x**2 + y**2)<1:
        data1[counter,0] = x
        data1[counter,1] = y
        data1[counter,2] = 1
        counter+=1

counter = 0
while counter < 1000:
    x = np.random.uniform(low=-2,high=2)
    y = np.random.uniform(low=-2,high=2)
    if (x**2 + y**2)>1:
        if (x**2 + y**2)<3:
            data2[counter,0] = x
            data2[counter,1] = y
            data2[counter,2] = 2
            counter+=1


practice1 = np.concatenate((data1,data2))
np.random.shuffle(practice1)

print(practice1)

plt.scatter(data1[:,0], data1[:,1],color="red", alpha=0.3)
plt.scatter(data2[:,0], data2[:,1],color="blue",alpha=0.3)
# Out:
# [[ 0.50885708 -1.52231383  2.        ]
#  [ 0.6691501   0.52560694  1.        ]
#  [-0.18250044 -0.68894901  1.        ]
#  ...
#  [-1.08549179 -0.06918016  2.        ]
#  [-0.30339803 -0.44889812  1.        ]
#  [-0.5795532  -0.52376342  1.        ]]

# %%
from sklearn import svm

trainfeatures3 = practice1[0:1200, 0:2]
trainlabels3 = practice1[0:1200, 2]

testfeatures3 = practice1[1200:, 0:2]
testlabels3 = practice1[1200:, 2]


rbf_svc = svm.SVC(kernel='rbf')
rbf_svc.kernel


rbf_svc.fit(trainfeatures3, trainlabels3)

test = rbf_svc.predict(testfeatures3)
count = 0
for i in range(800): 
    if testlabels3[i] == test[i]:
        count += 1

accuracy = count / 800
print("accuracy is ", accuracy*100,"%")
# Out:
# accuracy is  98.875 %

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))
data3 = np.zeros((1000,4))


x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = -2
y1 = -1
z1 = -3
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1

x1 = -1
y1 = 2
z1 = -1.5
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<2:
        data3[counter,0] = x2
        data3[counter,1] = y2
        data3[counter,2] = z2
        data3[counter,3] = 3
        counter+=1

practice2 = np.concatenate((data1,data2,data3))
np.random.shuffle(practice2)
print(practice2)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
ax.scatter3D(data3[:,0], data3[:,1], data3[:,2], color = "red",alpha=0.2)
plt.show()
# Out:
# [[-1.12052168  1.88620945 -2.12724544  3.        ]
#  [-1.43662717  2.92385982 -0.98995931  3.        ]
#  [-0.33298072  2.14906639 -0.95119296  3.        ]
#  ...
#  [ 3.19724755 -1.19598722 -0.79282322  1.        ]
#  [ 2.45225249 -2.23381896 -1.60350312  1.        ]
#  [-0.99702492  1.35247955 -2.40805408  3.        ]]

# %%
from sklearn import svm

trainfeatures2 = practice2[0:2000, 0:3]
trainlabels2 = practice2[0:2000, 3]

testfeatures2 = practice2[2000:, 0:3]
testlabels2 = practice2[2000:, 3]

classifier = svm.SVC()

classifier.fit(trainfeatures2, trainlabels2)

test = classifier.predict(testfeatures2)
count = 0
for i in range(1000): 
    if testlabels2[i] == test[i]:
        count += 1

accuracy = count / 1000
print("accuracy is ", accuracy*100,"%")
# Out:
# accuracy is  100.0 %

# %%
data1 = np.zeros((1000,4))
data2 = np.zeros((1000,4))

x1 = 3
y1 = -2
z1 = -1
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data1[counter,0] = x2
        data1[counter,1] = y2
        data1[counter,2] = z2
        data1[counter,3] = 1
        counter+=1

x1 = 3
y1 = -2
z1 = 0.5
counter = 0
while counter < 1000:
    x2 = np.random.uniform(low=-1,high=1) + x1
    y2= np.random.uniform(low=-1,high=1) + y1
    z2 = np.random.uniform(low=-1,high=1) + z1 
    if ((x1-x2)**2 + (y1-y2)**2+(z1-z2)**2)<1:
        data2[counter,0] = x2
        data2[counter,1] = y2
        data2[counter,2] = z2
        data2[counter,3] = 2
        counter+=1


practice3 = np.concatenate((data1,data2))
np.random.shuffle(practice3)
print(practice3)

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data1[:,0], data1[:,1], data1[:,2], color = "green",alpha=0.2)
ax.scatter3D(data2[:,0], data2[:,1], data2[:,2], color = "blue",alpha=0.2)
plt.show()
# Out:
# [[ 2.69386884 -2.13029136  0.9398999   2.        ]
#  [ 2.74809406 -1.37904639 -0.29824813  1.        ]
#  [ 3.42452494 -2.2655843  -1.6549481   1.        ]
#  ...
#  [ 3.75631851 -1.77077876  0.20955205  2.        ]
#  [ 3.27731018 -2.55510913 -0.48464042  1.        ]
#  [ 2.7656956  -2.5480398   0.28876253  2.        ]]

# %%
from sklearn import svm

trainfeatures = practice3[0:1200, 0:3]
trainlabels = practice3[0:1200, 3]

testfeatures = practice3[1200:, 0:3]
testlabels = practice3[1200:, 3]

classifier = svm.SVC()

classifier.fit(trainfeatures, trainlabels)

test = classifier.predict(testfeatures)
count = 0
for i in range(800): 
    if testlabels[i] == test[i]:
        count += 1

accuracy = count / 800
print("accuracy is ", accuracy*100,"%")
# Out:
# accuracy is  96.625 %

# %%
#test
